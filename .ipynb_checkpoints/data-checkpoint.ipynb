# %%
import pandas as pd
import numpy as np
import datetime

import matplotlib.pyplot as plt
import seaborn as sns

# %%
students = pd.read_csv("students.csv")
swipes = pd.read_csv("swipes.csv")

# %%
students.head()
# Out:
#    Student GENDER_CD  CLASS_YR   Fall_2011    Freshman
# 0    67130         F      2012    Columbus  Charleston
# 1   101400         F      2012  Providence       Fargo
# 2   118306         F      2012      Dallas     Detroit
# 3    30533         M      2012    New York     Detroit
# 4   185911         M      2012    New York      Newark

# %%
swipes.head()
# Out:
#    178  8/30/2011 0:00:00   5:22:32 PM  Dinner  MUAero01  14MF  0
# 0  178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01  14MF  0
# 1  178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1  14MF  0
# 2  178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01  14MF  0
# 3  178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01  14MF  0
# 4  178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01  14MF  0

# %%
students[students['Student'] == 239]
# Out:
#      Student GENDER_CD  CLASS_YR Fall_2011 Freshman
# 592      239         M      2013    Eugene   Topeka

# %%
swipes.columns = ['student_id', 'date', 'time', 'meal', 'location', 'meal_plan', 'unknown']

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(len(swipes))
# Out:
# 337174

# %%
athletes = swipes[swipes['meal_plan'] == 'ATHL']

# %%
print(len(athletes))
# Out:
# 134

# %%
print(len(swipes['student_id'].unique()))
# Out:
# 1620

# %% [markdown]
# # Sort by date

# %%
swipes.sort_values(by='date', ascending=False)
# Out:
#         student_id               date         time    meal  location  \
# 246854      156078   9/9/2011 0:00:00  12:37:56 PM   Lunch   THAero1
# 129232       82318   9/9/2011 0:00:00  12:07:21 PM   Lunch   THAero1
# 188555      119039   9/9/2011 0:00:00   5:49:37 PM  Dinner   THAero1
# 188769      119309   9/9/2011 0:00:00  12:31:55 PM   Lunch  MUAero01
# 188770      119309   9/9/2011 0:00:00   6:23:08 PM  Dinner   THAero1
# ...            ...                ...          ...     ...       ...
# 273077      174154  10/1/2011 0:00:00  11:49:48 AM  Brunch  MUAero01
# 273078      174154  10/1/2011 0:00:00   5:24:10 PM  Dinner   THAero1
# 322094      205576  10/1/2011 0:00:00   5:54:57 PM  Dinner   THAero1
# 322093      205576  10/1/2011 0:00:00  12:56:56 PM  Brunch   THAero1
# 332184      212501  10/1/2011 0:00:00   5:01:53 PM  Dinner  MUAero01
#
#        meal_plan  unknown
# 246854      19MF        0
# 129232      19MF        0
# 188555      19MF        0
# 188769      19MF        0
# 188770      19MF        0
# ...          ...      ...
# 273077      19MF        0
# 273078      19MF        0
# 322094      19MF        0
# 322093      19MF        0
# 332184      19MF        0
#
# [337174 rows x 7 columns]

# %%
students.head()
# Out:
#    Student GENDER_CD  CLASS_YR   Fall_2011    Freshman
# 0    67130         F      2012    Columbus  Charleston
# 1   101400         F      2012  Providence       Fargo
# 2   118306         F      2012      Dallas     Detroit
# 3    30533         M      2012    New York     Detroit
# 4   185911         M      2012    New York      Newark

# %%
id_to_dorm = dict()
id_to_freshman = dict()
id_to_class = dict()
id_to_gender = dict()

for i in range(len(students)):
    row = students.iloc[i]
    student_id = row['Student']
    gender = row['GENDER_CD']
    class_year = row['CLASS_YR']
    current_dorm = row['Fall_2011']
    freshman_dorm = row['Freshman']

    id_to_dorm[student_id] = current_dorm
    id_to_freshman[student_id] = freshman_dorm
    id_to_class[student_id] = class_year
    id_to_gender[student_id] = gender

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
swipes['current_dorm'] = swipes['student_id'].map(id_to_dorm)
swipes['first_dorm'] = swipes['student_id'].map(id_to_freshman)
swipes['class_year'] = swipes['student_id'].map(id_to_class)
swipes['gender'] = swipes['student_id'].map(id_to_gender)

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown current_dorm    first_dorm  class_year gender
# 0        0   Providence  Indianapolis        2014      M
# 1        0   Providence  Indianapolis        2014      M
# 2        0   Providence  Indianapolis        2014      M
# 3        0   Providence  Indianapolis        2014      M
# 4        0   Providence  Indianapolis        2014      M

# %%
print(len(swipes[swipes['meal_plan'] == '14MF']))
print(len(swipes[swipes['meal_plan'] == '19MF']))
# Out:
# 45869
# 284997

# %%
students.head()
# Out:
#    Student GENDER_CD  CLASS_YR   Fall_2011    Freshman
# 0    67130         F      2012    Columbus  Charleston
# 1   101400         F      2012  Providence       Fargo
# 2   118306         F      2012      Dallas     Detroit
# 3    30533         M      2012    New York     Detroit
# 4   185911         M      2012    New York      Newark

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown current_dorm    first_dorm  class_year gender
# 0        0   Providence  Indianapolis        2014      M
# 1        0   Providence  Indianapolis        2014      M
# 2        0   Providence  Indianapolis        2014      M
# 3        0   Providence  Indianapolis        2014      M
# 4        0   Providence  Indianapolis        2014      M

# %%
meal_plans = dict()
already_checked = []

for i in range(len(swipes)):
    row = swipes.iloc[i]
    current_id = row['student_id']
    meal_plan = row['meal_plan']

    if current_id not in already_checked:
        meal_plans[current_id] = meal_plan
        already_checked.append(current_id)
    else:
        continue

# %%
students['meal_plan'] = students['Student'].map(meal_plans)

# %%
students.head()
# Out:
#    Student GENDER_CD  CLASS_YR   Fall_2011    Freshman meal_plan
# 0    67130         F      2012    Columbus  Charleston      19MF
# 1   101400         F      2012  Providence       Fargo      19MF
# 2   118306         F      2012      Dallas     Detroit      14MF
# 3    30533         M      2012    New York     Detroit      19MF
# 4   185911         M      2012    New York      Newark      19MF

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown current_dorm    first_dorm  class_year gender
# 0        0   Providence  Indianapolis        2014      M
# 1        0   Providence  Indianapolis        2014      M
# 2        0   Providence  Indianapolis        2014      M
# 3        0   Providence  Indianapolis        2014      M
# 4        0   Providence  Indianapolis        2014      M

# %%
old_dates = list(swipes['date'])
new_dates = [i[:-8] for i in old_dates]
swipes['new_date'] = new_dates

# %%
swipes['date_time'] = swipes['new_date'] + ' ' + swipes['time']

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown current_dorm    first_dorm  class_year gender   new_date  \
# 0        0   Providence  Indianapolis        2014      M  8/31/2011
# 1        0   Providence  Indianapolis        2014      M  8/31/2011
# 2        0   Providence  Indianapolis        2014      M   9/1/2011
# 3        0   Providence  Indianapolis        2014      M   9/1/2011
# 4        0   Providence  Indianapolis        2014      M   9/2/2011
#
#                date_time
# 0  8/31/2011 12:21:06 PM
# 1   8/31/2011 5:24:17 PM
# 2    9/1/2011 1:05:55 PM
# 3    9/1/2011 5:32:16 PM
# 4   9/2/2011 11:21:00 AM

# %%
swipes['date_time'] = pd.to_datetime(swipes['date_time'])

# %%
swipes.head()
# Out:
#    student_id               date         time    meal  location meal_plan  \
# 0         178  8/31/2011 0:00:00  12:21:06 PM   Lunch  MUAero01      14MF
# 1         178  8/31/2011 0:00:00   5:24:17 PM  Dinner   THAero1      14MF
# 2         178   9/1/2011 0:00:00   1:05:55 PM   Lunch  MUAero01      14MF
# 3         178   9/1/2011 0:00:00   5:32:16 PM  Dinner  MUAero01      14MF
# 4         178   9/2/2011 0:00:00  11:21:00 AM   Lunch  MUAero01      14MF
#
#    unknown current_dorm    first_dorm  class_year gender   new_date  \
# 0        0   Providence  Indianapolis        2014      M  8/31/2011
# 1        0   Providence  Indianapolis        2014      M  8/31/2011
# 2        0   Providence  Indianapolis        2014      M   9/1/2011
# 3        0   Providence  Indianapolis        2014      M   9/1/2011
# 4        0   Providence  Indianapolis        2014      M   9/2/2011
#
#             date_time
# 0 2011-08-31 12:21:06
# 1 2011-08-31 17:24:17
# 2 2011-09-01 13:05:55
# 3 2011-09-01 17:32:16
# 4 2011-09-02 11:21:00

# %%
# swipes.to_csv("swipes_updated1.csv")

# %%
# students.to_csv("students_updated1.csv")

# %%
swipes['time'] = pd.to_datetime(swipes['time'])
# Out:
# /tmp/ipykernel_66258/3274860016.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   swipes['time'] = pd.to_datetime(swipes['time'])

# %%
swipes['time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
thorne_dinner = swipes[(swipes['meal'] == 'Dinner') & (swipes['location'] == 'THAero1')]

# %%
min_dinner_time = min(thorne_dinner['time'])
max_dinner_time = max(thorne_dinner['time'])

# %%
five_min = datetime.timedelta(0,300)

# %%
error = False
dinner_buckets = []
current_time = min_dinner_time

while error == False:
    if current_time >= max_dinner_time:
        dinner_buckets.append(current_time)
        error = True
    else:
        dinner_buckets.append(current_time)
        current_time = current_time + five_min

# %% [markdown]
# ## Get the number of swipes during each time interval (bucket)

# %%
test_lower = dinner_buckets[10]
test_upper = dinner_buckets[11]

# get all swipes between these types
test = swipes[(swipes['time'] >= test_lower) & (swipes['time'] <= test_upper)]
test.head()
# Out:
#      student_id                date                time    meal  location  \
# 1           178   8/31/2011 0:00:00 2024-02-29 17:24:17  Dinner   THAero1
# 55          178   9/28/2011 0:00:00 2024-02-29 17:21:04  Dinner  MUAero01
# 59          178   9/30/2011 0:00:00 2024-02-29 17:24:24  Dinner  MUAero01
# 160         178  11/28/2011 0:00:00 2024-02-29 17:20:27  Dinner  MUAero01
# 400         239   12/6/2011 0:00:00 2024-02-29 17:24:45  Dinner   THAero1
#
#     meal_plan  unknown current_dorm    first_dorm  class_year gender  \
# 1        14MF        0   Providence  Indianapolis        2014      M
# 55       14MF        0   Providence  Indianapolis        2014      M
# 59       14MF        0   Providence  Indianapolis        2014      M
# 160      14MF        0   Providence  Indianapolis        2014      M
# 400      19MF        0       Eugene        Topeka        2013      M
#
#        new_date           date_time
# 1     8/31/2011 2011-08-31 17:24:17
# 55    9/28/2011 2011-09-28 17:21:04
# 59    9/30/2011 2011-09-30 17:24:24
# 160  11/28/2011 2011-11-28 17:20:27
# 400   12/6/2011 2011-12-06 17:24:45

# %%
num_swipes = []
all_bounds = []

# %%
for i in range(len(dinner_buckets)):
    try:
        lower_bound = dinner_buckets[i]
        upper_bound = dinner_buckets[i+1]
    except:
        lower_bound = dinner_buckets[i]
        bounded = swipes[(swipes['time'] >= lower_bound)]
        num_swipes.append(len(bounded))
        all_bounds.append(str(lower_bound))
        # all_bounds.append((str(lower_bound), 'end'))
        
    
    bounded = swipes[(swipes['time'] >= lower_bound) & (swipes['time'] <= upper_bound)]
    num_swipes.append(len(bounded))

    new_lower_bound = str(lower_bound)[11:]
    if i != 0:
        if all_bounds[i-1][0:2] == new_lower_bound[0:2]:
            new_lower_bound = new_lower_bound[3:]

    all_bounds.append(new_lower_bound)
    # new_lower_bound = str(lower_bound)[11:]
    # new_upper_bound = str(upper_bound)[11:]
    # all_bounds.append((new_lower_bound, new_upper_bound))

# %%
# print(len(num_swipes))
# print(len(all_bounds))
# new_all_bounds = [str(i[0]) + '-' + str(i[1]) for i in all_bounds]
print(new_all_bounds)
# Out:
# ['16:30:00-16:35:00', '16:35:00-16:40:00', '16:40:00-16:45:00', '16:45:00-16:50:00', '16:50:00-16:55:00', '16:55:00-17:00:00', '17:00:00-17:05:00', '17:05:00-17:10:00', '17:10:00-17:15:00', '17:15:00-17:20:00', '17:20:00-17:25:00', '17:25:00-17:30:00', '17:30:00-17:35:00', '17:35:00-17:40:00', '17:40:00-17:45:00', '17:45:00-17:50:00', '17:50:00-17:55:00', '17:55:00-18:00:00', '18:00:00-18:05:00', '18:05:00-18:10:00', '18:10:00-18:15:00', '18:15:00-18:20:00', '18:20:00-18:25:00', '18:25:00-18:30:00', '18:30:00-18:35:00', '18:35:00-18:40:00', '18:40:00-18:45:00', '18:45:00-18:50:00', '18:50:00-18:55:00', '18:55:00-19:00:00', '19:00:00-19:05:00', '19:05:00-19:10:00', '19:10:00-19:15:00', '19:15:00-19:20:00', '19:20:00-19:25:00', '19:25:00-19:30:00', '19:30:00-19:35:00', '19:35:00-19:40:00', '19:40:00-19:45:00', '19:45:00-19:50:00', '2024-02-29 19:50:00-end', '19:50:00-19:50:00']

# %%
all_bounds
# Out:
# ['16:30:00',
#  '35:00',
#  '16:40:00',
#  '45:00',
#  '16:50:00',
#  '55:00',
#  '17:00:00',
#  '05:00',
#  '17:10:00',
#  '15:00',
#  '17:20:00',
#  '25:00',
#  '17:30:00',
#  '35:00',
#  '17:40:00',
#  '45:00',
#  '17:50:00',
#  '55:00',
#  '18:00:00',
#  '05:00',
#  '18:10:00',
#  '15:00',
#  '18:20:00',
#  '25:00',
#  '18:30:00',
#  '35:00',
#  '18:40:00',
#  '45:00',
#  '18:50:00',
#  '55:00',
#  '19:00:00',
#  '05:00',
#  '19:10:00',
#  '15:00',
#  '19:20:00',
#  '25:00',
#  '19:30:00',
#  '35:00',
#  '19:40:00',
#  '45:00',
#  '2024-02-29 19:50:00',
#  '19:50:00']

# %%
plt.figure(figsize=(50,10))
sns.set()
sns.lineplot(x=all_bounds, y=num_swipes)
# Out:
# <Axes: >
